# %% [markdown]
# # Progetto Fondamenti di Machine Learning
#
# Il progetto si articola in **quattro fasi principali**: la definizione manuale di classificatori sul dataset "manuale.csv", l'analisi esplorativa del dataset "training.csv" per verificare la qualità dei dati e identificare pattern significativi, l'ottimizzazione delle performance dei classificatori implementati, e infine l'addestramento di modelli avanzati utilizzando Scikit-Learn con separazione appropriata tra training set e test set.

# %% [markdown]
# ---
# # Primo task
#
# Nel primo task ci viene chiesto di definire manualmente più classificatori sul file "manuale.csv", adottando almeno due dei modelli illustrati a lezione, e valutando le prestazioni da loro ottenute sullo stesso file “manuale.csv”; dopo aver illustrato i passi per adattare i modelli ai dati, implementare i classificatori in Python, utilizzando eventualmente delle API;
#
# ### Import necessari
#
# In questa sezione verranno inseriti i vari import necessari per eseguire il primo task.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression # per costruire il modello di regressione logistica
from sklearn.metrics import accuracy_score # utile per le metriche di accuratezza
from sklearn.tree import DecisionTreeClassifier # per costruire il modello di albero decisionale 
from sklearn.preprocessing import StandardScaler # per scalare i dati (utile per il modello di regressione logistica)
from sklearn.metrics import confusion_matrix
import seaborn as sns #utile per la visualizzazione dei dati, specialmente pairplots e heatmap
import matplotlib.pyplot as plt #utile per un controllo dettagliato delle visualizzazioni

# %% [markdown]
# ### Esaminiamo la struttura del dataset
#
# Per prima cosa vogliamo esaminare la struttura del dataset usando più classificatori, in questo modo ci permetterà nella preparazione e comprensione dei dati:

# %%
# Carichiamo il file CSV specificando il delimitatore, nel nostro caso è il punto e virgola.
df = pd.read_csv("../specifiche/data/manuale.csv", sep=';')

# Esaminiamo la struttura del dataset

# Per prima cosa ci ricaviamo la dimensione del dataset
print("Dimensioni del dataset:", df.shape)
# Out:
# Dimensioni del dataset: (25, 12)

# %%
# Dopodiché visualizzzaimo tutto il dataset essendo abbastanza piccolo
df
# Out:
#     Età Genere  Fumatore  Ex-Fumatore  Non-Fumatore        Data  \
# 0    43      F     False        False          True  05/06/2024
# 1    79      M     False         True         False  10/08/2024
# 2    81      M      True        False         False  04/08/2024
# 3    81      M     False        False          True  16/08/2024
# 4    48      F     False        False          True  27/06/2024
# 5    82      M     False        False          True  02/02/2024
# 6    72      M     False        False          True  28/06/2024
# 7    78      M     False         True         False  16/07/2024
# 8    82      M     False        False          True  24/03/2024
# 9    81      M     False        False          True  24/05/2024
# 10   82      M     False        False          True  10/07/2024
# 11   81      M     False         True         False  30/08/2024
# 12   81      M     False         True         False  05/12/2024
# 13   81      M     False         True         False  23/07/2024
# ...

# %% [markdown]
# Da questo output possiamo trarre che il dataset rappresenta dati medici di pazienti per la classificazione del livello di allerta (GREEN/YELLOW/RED). Essendo un dataset con dimensioni ridotte verifichiamo se è presente una distribuzione bilanciata delle classi target.

# %%
# Facciamo il conteggio  
target_counts = df['Allerta?'].value_counts()
print(target_counts)
print(f"\nGREEN({target_counts['GREEN']}), YELLOW({target_counts['YELLOW']}), RED({target_counts['RED']})")
# Out:
# Allerta?
# YELLOW    9
# GREEN     8
# RED       8
# Name: count, dtype: int64
#
# GREEN(8), YELLOW(9), RED(8)

# %% [markdown]
# Da questo output possiamo confermare che è presente una **distribuzione ben bilanciata**. Passiamo ad analizzare i tipi di dato delle varie colonne.

# %%
print(df.dtypes)
# Out:
# Età                    int64
# Genere                object
# Fumatore                bool
# Ex-Fumatore             bool
# Non-Fumatore            bool
# Data                  object
# Frequenza Cardiaca     int64
# SpO2                   int64
# OssigenoTerapia       object
# DopoTest6Minuti         bool
# Temperatura           object
# Allerta?              object
# dtype: object

# %% [markdown]
# ## Osservazioni a seguito dell'analisi del dataset
#
# Durante l'analisi sono emmersi **quattro problemi** che richiedono interventi di pulizia. Inoltre, per garantire la compatibilità con gli algoritmi di machine learning, le variabili dovranno essere convertite in un formato numerico.
#
# ### Problema 1
#
# Le temperature sono registrate con la **virgola come separatore decimale** invece del punto, seguendo la convenzione italiana. Questo impedisce la conversione automatica in formato numerico. Senza conversione, la colonna risulterebbe inutilizzabile.
#
# Per risolvere questo problema passiamo a sostituire la virgola con il punto nella colonna temperatura.

# %%
# Carichiamo il dataset in un'altra variabile che rappresenterà il nostro dataset 'pulito' 

df_clean = pd.read_csv("../specifiche/data/manuale.csv", sep=';')
df_clean['Temperatura'] = df_clean['Temperatura'].str.replace(',', '.').astype(float)

# Per verificare che la modifica sia andata a buon fine stampiamo le prime 5 righe del dataset

df_clean.head()
# Out:
#    Età Genere  Fumatore  Ex-Fumatore  Non-Fumatore        Data  \
# 0   43      F     False        False          True  05/06/2024
# 1   79      M     False         True         False  10/08/2024
# 2   81      M      True        False         False  04/08/2024
# 3   81      M     False        False          True  16/08/2024
# 4   48      F     False        False          True  27/06/2024
#
#    Frequenza Cardiaca  SpO2 OssigenoTerapia  DopoTest6Minuti  Temperatura  \
# 0                  91    99    venturi_mask            False         36.3
# 1                  70    93    venturi_mask            False         36.0
# 2                 124    91              no            False         36.5
# 3                 120    92              ox            False         36.6
# 4                  97    95    venturi_mask            False         36.1
#
#   Allerta?
# 0    GREEN
# 1   YELLOW
# 2   YELLOW
# 3      RED
# 4   YELLOW

# %% [markdown]
# ## Problema 2
#
# Lo status del fumatore è rappresentato tramite **3 colonne booleane separate**:
# - `Fumatore`: true/false
# - `Ex-Fumatore`: true/false
# - `Non-Fumatore`: true/false
#
# **Analisi della ridondanza:**
# - Ogni paziente ha **esattamente una** delle tre colonne a `true`
# - Esse infatti rappresentano la stessa informazione in formato scomodo
#
# **Esempio:**
# ```
# Fumatore: false | Ex-Fumatore: true  | Non-Fumatore: false  → Ex-Fumatore
# Fumatore: true  | Ex-Fumatore: false | Non-Fumatore: false  → Fumatore
# Fumatore: false | Ex-Fumatore: false | Non-Fumatore: true   → Non-Fumatore
# ```
#
# Per risolvere questo problema creiamo una nuova colonna chiamatas `StatoFumo` che indicherà i vari status indicati nelle altre colonne.

# %%
# Per prima cosa definiamo le condizioni per categoriizzare lo status da fumatore
conditions = [
    # Prima condizione: fumatore
    df_clean['Fumatore'] == 1,
    # Seconda condizione: ex fumatore
    (df_clean['Fumatore'] == 0) & (df_clean['Ex-Fumatore'] == 1)
]

# Definiamo le scelte per ogni condizione
choices = ['Fumatore', 'Ex-Fumatore']

# Creiamo una nuova colonna usando numpy.select con 'Non-Fumatore' come status di default
df_clean['StatoFumo'] = np.select(conditions, choices, default='Non-Fumatore')

# Eliminiamo le colonne che non ci servono più
df_clean = df_clean.drop(columns=['Fumatore', 'Ex-Fumatore', 'Non-Fumatore'])

# Stampiamo le prime 5 righe per verificare che tutto sia corretto.
df_clean.head()
# Out:
#    Età Genere        Data  Frequenza Cardiaca  SpO2 OssigenoTerapia  \
# 0   43      F  05/06/2024                  91    99    venturi_mask
# 1   79      M  10/08/2024                  70    93    venturi_mask
# 2   81      M  04/08/2024                 124    91              no
# 3   81      M  16/08/2024                 120    92              ox
# 4   48      F  27/06/2024                  97    95    venturi_mask
#
#    DopoTest6Minuti  Temperatura Allerta?     StatoFumo
# 0            False         36.3    GREEN  Non-Fumatore
# 1            False         36.0   YELLOW   Ex-Fumatore
# 2            False         36.5   YELLOW      Fumatore
# 3            False         36.6      RED  Non-Fumatore
# 4            False         36.1   YELLOW  Non-Fumatore

# %% [markdown]
# ## Problema 3
#
# Nel contesto di un **sistema di triage medico**, la data della visita **non dovrebbe influenzare** il livello di allerta del paziente. I parametri vitali (frequenza cardiaca, SpO2, temperatura) sono **istantanei** e indipendenti dal momento della misurazione.
#
# Potrebbero esistere dei pattern temporali, però, la decisione è stata quella di rimuovere la colonna della data per mantere il focus sui **parametri clinici diretti.**

# %%
# Rimozione della colonna Data
df_clean = df_clean.drop(columns=['Data'])

# Stampiamo le colonne presenti per verificare 
print(f"• Colonne presenti: {list(df_clean.columns)}")
# Out:
# • Colonne presenti: ['Età', 'Genere', 'Frequenza Cardiaca', 'SpO2', 'OssigenoTerapia', 'DopoTest6Minuti', 'Temperatura', 'Allerta?', 'StatoFumo']

# %% [markdown]
# ## Definizione manuale classificatori
# In questa sezione definiremo manualmente più classificatori, e verificheremo le loro prestazioni tramite accuracy.
#  Andremo a definire un classificatore di tipo **Decision Tree** e <CONTINUA<

# %% [markdown]
# Andiamo a definire il classificatore **Decision Tree**.
#
# Per fare ciò, andiamo inanzitutto a visionre la media di alcune variabili raggruppate per **allerta**

# %%
cols = ['Età', 'Frequenza Cardiaca', 'SpO2', 'Temperatura', 'Allerta?']
df_clean_subset = df_clean[cols].copy()
tabella_medie = df_clean_subset.groupby('Allerta?').mean().round(1)
tabella_medie
# Out:
#            Età  Frequenza Cardiaca  SpO2  Temperatura
# Allerta?
# GREEN     70.0                80.1  96.1         36.5
# RED       81.5               120.9  91.4         36.6
# YELLOW    75.2               109.4  92.2         36.5

# %% [markdown]
# Possiamo fare le seguenti osservazioni:
# - per l'allerta **Rossa** il livello medio di **Frequenza Cardiaca** è molto più alto che nelle altre fasce di allerta
# - il livello medio di **Temperatura** è circa lo stesso per ogni fascia di allerta
# - il livello medio di **SpO2** è più alto nella fascia di allerta **Verde**
#
# Date le seguenti osservazioni possiamo costruire il seguente **albero di decisione** su 3 Feature: Frequenza cardiaca, SpO2 e Ossigeno terapia

# %%
def decision_tree_fc_spo2_ot(fc, spo2, ot):
    if (fc > 112 or spo2 < 92) and ot == "ox":
        return 'RED'
    elif fc <= 95 and spo2 >= 94:
        return 'GREEN'
    else:
        return 'YELLOW'

# %%
def accuracy(y_true, y_pred):
    return np.sum(y_pred == y_true) / len(y_true)

# %% [markdown]
# Successivamente, andiamo a separare la colonna delle predizioni e misuriamo la **Accuracy** del nostro classificatore

# %%
Y_true = df_clean['Allerta?']

Y_pred = df.apply(lambda row: decision_tree_fc_spo2_ot(row['Frequenza Cardiaca'], row['SpO2'], row['OssigenoTerapia']), axis=1)

acc = accuracy(Y_true, Y_pred)
print("Accuracy del Decision Tree manuale:", round(acc * 100, 2), "%")
# Out:
# Accuracy del Decision Tree manuale: 92.0 %

# %% [markdown]
# L'accuratezza del nostrao classificatore è del **92%**, di cosenguenza devono esistere delle predizioni errate. Andiamo a vedere quali di queste predizioni è errata tramite **matrice di confusione**.

# %%
confusion_matrix(df['Allerta?'], Y_pred, labels=['GREEN', 'YELLOW', 'RED'])
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d',
            xticklabels=['GREEN', 'YELLOW', 'RED'],
            yticklabels=['GREEN', 'YELLOW', 'RED'])
plt.xlabel('Predetto')
plt.ylabel('Reale')
plt.title('Matrice di Confuzione')
plt.show()

# %% [markdown]
# Dalla matrice di confusione possiamo chiaramante vedere come il modello abbia sbagliato a predirre due casi, entrambi facenti parte della fascia di allerta **Gialla**. Il resto delle classi sono state predette correttamente.

# %% [markdown]
# ## Problema 4
#
# Gli algoritmi di machine learning tradizionali operano in spazi vettoriali numerici e non possono processare direttamente variabili categoriche. Per questo motivo, le variabili qualitative verranno trasformate in **valori interi** attraverso una mappatura manuale.
#
# Ad esempio:
# - `M` o `F` per la colonna di Genere, verrano convertiti in `0` oppure `1`.
# - Per `StatoFumo`, verrà definita una scala ordinata con
#   - Non-Fumatore = 0
#   - Ex-Fumatore = 1
#   - Fumatore = 2

# %%
# Per prima cosa creiamo i vari mapping originali

# Mappatura originale per la colonna Genere
genere_map = {'M': 0, 'F': 1}
# Mappatura originale per la colonna OssigenoTerapia
ossigeno_map = {'no': 0, 'venturi_mask': 1, 'ox': 2}
# Mappatura originale per la colonna allerta
allerta_map = {'GREEN': 0, 'RED': 1, 'YELLOW': 2}
# Mappatura originale per la colonna StatoFumo
stato_map = {'Non-Fumatore': 0, 'Ex-Fumatore': 1, 'Fumatore': 2}

# Conversione numerica della colonna genere
df_clean['Genere'] = df_clean['Genere'].map(genere_map)
# Conversione numerica della colonna OssigenoTerapia
df_clean['OssigenoTerapia'] = df_clean['OssigenoTerapia'].map(ossigeno_map)
# Conversione numerica della colonna Allerta?
df_clean['Allerta?'] = df_clean['Allerta?'].map(allerta_map)
# Conversione numerica della colonna StatoFumo
df_clean['StatoFumo'] = df_clean['StatoFumo'].map(stato_map)

# Alla fine della conversione, eliminiamo le righe che hanno valori nulli
df_clean = df_clean.dropna()
print(df_clean.dtypes)
# Out:
# Età                     int64
# Genere                  int64
# Frequenza Cardiaca      int64
# SpO2                    int64
# OssigenoTerapia         int64
# DopoTest6Minuti          bool
# Temperatura           float64
# Allerta?                int64
# StatoFumo               int64
# dtype: object

# %% [markdown]
# ## Implementazione dei classificatori
#
# Per questo progetto sono stati selezionati due algoritmi di machine learning complementari:
# - Logistic regression, che nel nostro caso ci è molto utile per **classificaizone multi-classe**.
# - Decision tree, in quanto la struttura ad albero rispecchia il **ragionamento medico decisionale** e può catturare relazione cmplesse che potrebbero essere non lineari.
#
# Per quanto riguarda il modello di **regressione logistica**, in quanto sensibile alla scala delle variabili, ossia features con range molto diversi (es. l'età:20-80 e frequenza cardiaca: 60-200), è necessaria la **standardizzazione delle features** in questo modo i dati vengono trasformati per far si che tutte le features contribuiscono equamente al modello.
#
# Per prima cosa definiamo il nostro target, le nostre features sia standardizzate che non (in quanto il modello di decision tree non ha bisogno della standardizzazione delle features).

# %%
# Target: variabile da predire
y = df_clean['Allerta?']

# Features: tutte le colonne tranne il target
X = df_clean.drop(['Allerta?'], axis=1)

# Standardizzazione per Logistic Regression
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X)

print(f"Shape delle features: {X.shape}")
print(f"Shape del target: {y.shape}")
print(f"Shape delle features standardizzate: {X_scaled.shape}")
# Out:
# Shape delle features: (25, 8)
# Shape del target: (25,)
# Shape delle features standardizzate: (25, 8)

# %% [markdown]
# ### Logistic Regression
#
# Il primo classificatore implementato è la regressione logistica, che richiede l'utilizzo delle features standardizzate. Una volta addestrato il modello sui dati di training, vengono generate le predizioni sui livelli di allerta e **calcolata l'accuratezza** per misurare l'efficacia del classificatore nel distinguere correttamente tra le diverse classi.

# %%
# Modello 1: Logistic Regression

# Creiamo un'istanza per il modello
model_lr = LogisticRegression()

# Dopodiché addestriamo il modello sulle features e sulla variabile target
model_lr.fit(X_scaled, y)
# Out:
# LogisticRegression()

# %%
# Predizione e valutazione del modello

# Genera le predizioni utilizzando il modello addestrato
y_pred_lr = model_lr.predict(X_scaled)

# Calcola l'accuratezza confrontando predizioni e valori reali
accuracy_lr = accuracy_score(y, y_pred_lr)

# Stampa l'accuratezza in percentuale
print("Accuratezza percentuale del modello Logistic Regression:", accuracy_lr * 100) # Print the accuracy as a percentage
# Out:
# Accuratezza percentuale del modello Logistic Regression: 92.0

# %% [markdown]
# Il modello di regressione logistica raggiunge **un'accuratezza del 92%**, dimostrando un'elevata capacità predittiva nel classificare i livelli di allerta

# %% [markdown]
# ### Decision Tree Classifier
# Il secondo classificatore implementato è l'albero decisionale, un algoritmo non lineare che costruisce un modello predittivo attraverso una struttura gerarchica ad albero, grazie alla sua struttura che **rispecchia il processo decisionale umano**. A differenza della regressione logistica, questo modello non richiede la standardizzazione delle features.

# %%
# Modello 2: Decision Tree

# Creiamo un'istanza per il modello
model_dt = DecisionTreeClassifier()

# Addestra il modello sulle features non standardizzate e sulla variabile target
model_dt.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Genera le predizioni utilizzando l'albero decisionale addestrato
y_pred_dt = model_dt.predict(X)

# Calcola l'accuratezza del modello Decision Tree
accuracy_dt = accuracy_score(y, y_pred_dt)


print("Accuratezza percentuale del modello Decision Tree:", accuracy_dt * 100) # Print the accuracy as a percentage
# Out:
# Accuratezza percentuale del modello Decision Tree: 96.0

# %% [markdown]
# Il Decision Tree raggiunge **un'accuratezza del 92%**, equiparando le performance della regressione logistica e confermando l'efficacia di entrambi gli approcci.

# %% [markdown]
# ---
#
# # Secondo task
#
# Nel secondo task ci viene chiesto di verificare che il dataset “training.csv” non contenga osservazioni palesemente errate ed effettuare l’analisi esplorativa del dataset rappresentando i risultati anche in forma grafica (boxplot e/o pairplot e matrice di correlazione).

# %% [markdown]
# ### Import necessari
# In questa cella sono riportati tutti gli import necessari per lo svolgimento del secondo task

# %%
import seaborn as sns #utile per la visualizzazione dei dati, specialmente pairplots e heatmap
import matplotlib.pyplot as plt #utile per un controllo dettagliato delle visualizzazioni

# %% [markdown]
# ### Esaminazione dataset
# Andiamo adesso a leggere (tramite pandas.read_csv) ed esaminare il file "_training.csv_", affinchè possiamo visualizare le informazioni generali relative alla struttura.

# %%
#durante il caricamento specifichiamo il separatore ";"
tr = pd.read_csv("../specifiche/data/training.csv", sep=";")

#utilizziamo shape per visulizzare le dimensioni del dataset (righe, colonne)
print("Dimensioni dataset(righe, colonne): ", tr.shape)
# Out:
# Dimensioni dataset(righe, colonne):  (569, 12)

# %%
#dato che non possiamo visualizzare l'intero dataset, visualizziamo le prime 5 (default) righe tramite "head"
tr.head()
# Out:
#    Età Genere  Fumatore  Ex-Fumatore Non-Fumatore        Data  \
# 0   43      F     False        False         True  04/06/2024
# 1   79      M     False         True        False  09/08/2024
# 2   81      M      True        False        False  03/08/2024
# 3   81      M     False        False         True  15/08/2024
# 4   48      F     False        False         True  26/06/2024
#
#    Frequenza Cardiaca  SpO2 OssigenoTerapia DopoTest6Minuti Temperatura  \
# 0               104.0  94.0              no           False          36
# 1                85.0  89.0              no           False        36,3
# 2               114.0  86.0              no           False        36,2
# 3                92.0  86.0              no           False        36,5
# 4                87.0  93.0              no           False          36
#
#   Allerta?
# 0    GREEN
# 1    GREEN
# 2      RED
# 3      RED
# 4   YELLOW

# %%
#utilizziamo successivamente "tail" per vedere le ultime 20 righe del dataset
tr.tail(n=20)
# Out:
#       Età Genere  Fumatore  Ex-Fumatore Non-Fumatore        Data  \
# 549   100      M     False        False         True  12/04/2024
# 550    78      F     False        False         True  24/04/2024
# 551    44      M     False        False         True  27/05/2024
# 552    77      F     False        False         True  27/02/2024
# 553    70      M     False         True        False  02/08/2024
# 554    82      M     False        False         True  08/03/2024
# 555    91      M      True        False        False  08/05/2024
# 556    75      M     False         True        False  21/08/2024
# 557    63      F     False        False         True  19/08/2024
# 558  1926      M     False        False         True  22/08/2024
# 559    62      M      True        False        False  23/02/2024
# 560    10      F     False        False         True  29/05/2024
# 561   101      M     False        False         True  13/12/2024
# ...

# %%
#utilizziamo dtypes per verificare i tipi delle colonne del dataset
print("Tipi di dato delle colonne del dataset")
print(tr.dtypes)
# Out:
# Tipi di dato delle colonne del dataset
# Età                     int64
# Genere                 object
# Fumatore                 bool
# Ex-Fumatore              bool
# Non-Fumatore           object
# Data                   object
# Frequenza Cardiaca    float64
# SpO2                  float64
# OssigenoTerapia        object
# DopoTest6Minuti        object
# Temperatura            object
# Allerta?               object
# dtype: object

# %% [markdown]
# ### Ossrevazioni sui tipi di dato
# Come si può notare dall'analisi dei tipi, la colonna "_temperatura_" è erroneamente considerata di tipo "_object_" invece che "_float64_":   questo è dovuto al fatto che viene usato come separatore decimale una **virgola** piuttosto che un **punto**. (La stessa cosa accadeva nel Primo task).
# Oltre a questo, le colonne che presentano tipo "_object_" andrebbero trasformate in valori numerici, affinchè il dataset possa essere usato per allenare un modello.

# %%
#prendiamo una copia del dataset originale
tr_clean = pd.read_csv("../specifiche/data/training.csv", sep=";")

# %%
print(tr_clean.dtypes)
# Out:
# Età                     int64
# Genere                 object
# Fumatore                 bool
# Ex-Fumatore              bool
# Non-Fumatore           object
# Data                   object
# Frequenza Cardiaca    float64
# SpO2                  float64
# OssigenoTerapia        object
# DopoTest6Minuti        object
# Temperatura            object
# Allerta?               object
# dtype: object

# %% [markdown]
# Andiamo a convertire il tipo della colonna _**Temperatura**_ in float: per prime cosa effettuiamo una sostituzione del sepratore decimale, dalla virgola al punto. Successivamente cambiamo il tipo della colona in float.

# %%
tr_clean['Temperatura'] = tr_clean['Temperatura'].str.replace(',', '.').astype(float)
#trasformazione dell tipo della colonna "Temperatura" e sostituzione della virgola con il punto

# %%
print(tr_clean.dtypes)
# Out:
# Età                     int64
# Genere                 object
# Fumatore                 bool
# Ex-Fumatore              bool
# Non-Fumatore           object
# Data                   object
# Frequenza Cardiaca    float64
# SpO2                  float64
# OssigenoTerapia        object
# DopoTest6Minuti        object
# Temperatura           float64
# Allerta?               object
# dtype: object

# %% [markdown]
# Come per il primo task, possiamo procedere alla rimozione della colonna "_**data**_".

# %%
tr_clean = tr_clean.drop(columns=['Data'])
tr_clean.head()
# Out:
#    Età Genere  Fumatore  Ex-Fumatore Non-Fumatore  Frequenza Cardiaca  SpO2  \
# 0   43      F     False        False         True               104.0  94.0
# 1   79      M     False         True        False                85.0  89.0
# 2   81      M      True        False        False               114.0  86.0
# 3   81      M     False        False         True                92.0  86.0
# 4   48      F     False        False         True                87.0  93.0
#
#   OssigenoTerapia DopoTest6Minuti  Temperatura Allerta?
# 0              no           False         36.0    GREEN
# 1              no           False         36.3    GREEN
# 2              no           False         36.2      RED
# 3              no           False         36.5      RED
# 4              no           False         36.0   YELLOW

# %% [markdown]
# Successivamente, esattamente come abbiamo fatto per il primo task, andiamo a restringere il dataset unendo le colonne relative alla informazioni sullo status di fumatore del paziente. A questo scopo, riportiamo la stessa osservazione fatta precedentemente.
#
# Ogni paziente ha **esattamente** una delle tre colonne a "True", esse infatti rappresentano la stessa informazione in formato scomodo. Di conseguenza andremo a unire queste tre colonne formando una nuova colonna **unica** e **categorica**.

# %%
# Per prima cosa definiamo le condizioni per categoriizzare lo status da fumatore
conditions = [
    # Prima condizione: fumatore
    tr_clean['Fumatore'] == 1,
    # Seconda condizione: ex fumatore
    (tr_clean['Fumatore'] == 0) & (tr_clean['Ex-Fumatore'] == 1)
]

# Definiamo le scelte per ogni condizione
choices = ['Fumatore', 'Ex-Fumatore']

# Creiamo una nuova colonna usando numpy.select con 'Non-Fumatore' come status di default
tr_clean['StatoFumo'] = np.select(conditions, choices, default='Non-Fumatore')

# Eliminiamo le colonne che non ci servono più
tr_clean = tr_clean.drop(columns=['Fumatore', 'Ex-Fumatore', 'Non-Fumatore'])

# Stampiamo le prime 5 righe per verificare che tutto sia corretto.
tr_clean.head()
# Out:
#    Età Genere  Frequenza Cardiaca  SpO2 OssigenoTerapia DopoTest6Minuti  \
# 0   43      F               104.0  94.0              no           False
# 1   79      M                85.0  89.0              no           False
# 2   81      M               114.0  86.0              no           False
# 3   81      M                92.0  86.0              no           False
# 4   48      F                87.0  93.0              no           False
#
#    Temperatura Allerta?     StatoFumo
# 0         36.0    GREEN  Non-Fumatore
# 1         36.3    GREEN   Ex-Fumatore
# 2         36.2      RED      Fumatore
# 3         36.5      RED  Non-Fumatore
# 4         36.0   YELLOW  Non-Fumatore

# %%
print(tr_clean.dtypes)
# Out:
# Età                     int64
# Genere                 object
# Frequenza Cardiaca    float64
# SpO2                  float64
# OssigenoTerapia        object
# DopoTest6Minuti        object
# Temperatura           float64
# Allerta?               object
# StatoFumo              object
# dtype: object

# %%
tr_clean.shape
# Out:
# (569, 9)

# %% [markdown]
# ## Analisi sui valori
# In questa sezione andiamo a verificare i valori del dataset, cercando valori palesemente errati.
#
# Inanzitutto andiamo a visionare le classi (o possibili valori) di alcune delle variabili nel dataset.

# %%
print("Possibili valori della variabile \"Ossigeno terapia\": ", tr_clean['OssigenoTerapia'].unique())
print("Possibili valori della variabile \"Allerta\": ", tr_clean['Allerta?'].unique())
print("Possibili valori della variabile \"Dopo test 6 minuti\": ", tr_clean['DopoTest6Minuti'].unique())
print("Possibili valori della variabile \"Genere\": ", tr_clean['Genere'].unique())
#questa variabile è sostanzialmente booleana, ma ha alcuni valori Null
# Out:
# Possibili valori della variabile "Ossigeno terapia":  ['no' 'venturi_mask' 'ox' nan]
# Possibili valori della variabile "Allerta":  ['GREEN' 'RED' 'YELLOW' 'true' nan]
# Possibili valori della variabile "Dopo test 6 minuti":  [False True nan]
# Possibili valori della variabile "Genere":  ['F' 'M']

# %% [markdown]
# Si noti come nella colonna **Allerta** (oltre al valore nullo) sia presente un valore "_true_". Questo (insieme ad altri valori palesemente errati) verrà gestito in seguito.

# %% [markdown]
# #### Successivamente eseguiremo un'analisi per verificare la presenza di valori palesemente errati

# %% [markdown]
# ### Valori Null
# Andiamo adesso a verificare se (ed eventualmente quali) il dataset contiene righe con valori "_Null_"

# %%
#adesso andiamo a verificre se il dataset contiene qualche valore Null tramite la funzione "isnull()" (verifica su colonne)
tr_clean.isnull().any()
#tr.isnull().all()
# Out:
# Età                   False
# Genere                False
# Frequenza Cardiaca     True
# SpO2                   True
# OssigenoTerapia        True
# DopoTest6Minuti        True
# Temperatura            True
# Allerta?               True
# StatoFumo             False
# dtype: bool

# %% [markdown]
# Da questo output capiamo che le colonne con esito "_True_" hanno almeno un valore "_Null_". Per vedere quali (e soprattutto, quante) righe contengono dei "_Null_" facciamo una selezione sul dataset dove compare almeno un valore "_Null_".

# %%
tr_clean[tr_clean.isnull().any(axis=1)]
#tramite "axis = 1" andiamo a considerare le righe piuttosto che le colonne
# Out:
#      Età Genere  Frequenza Cardiaca  SpO2 OssigenoTerapia DopoTest6Minuti  \
# 238  100      M                 NaN  89.0              no           False
# 311   43      F                91.0  99.0             NaN           False
# 355    6      M                 NaN   NaN             NaN             NaN
# 376   73      F                 NaN   NaN             NaN             NaN
# 378   24      M                 NaN   NaN             NaN             NaN
# 402   64      M                 NaN   NaN             NaN             NaN
# 406   57      M                 NaN   NaN             NaN             NaN
# 407   49      M                 NaN   NaN             NaN             NaN
# 423   90      M                 NaN   NaN             NaN             NaN
# 428   26      M                 NaN   NaN             NaN             NaN
# 433    8      M                 NaN   NaN             NaN             NaN
# 439   69      M                 NaN   NaN             NaN             NaN
# ...

# %%
print(tr_clean.isnull().sum())
#con questa operazione ci rendiamo conto di quanti valori "Null" abbia ogni colonna del dataset
# Out:
# Età                    0
# Genere                 0
# Frequenza Cardiaca    21
# SpO2                  20
# OssigenoTerapia       21
# DopoTest6Minuti       20
# Temperatura           20
# Allerta?              20
# StatoFumo              0
# dtype: int64

# %% [markdown]
# #### Andiamo adesso a gestire i valori null, tramite sistituzione oppure eliminazione di righe

# %% [markdown]
# In questo caso abbiamo diverse possibili soluzioni:
# - rimuovere le righe che presentano valori _Null_
# - sostituire con un valore **fisso**
# - sostituire con **media**, **mediana** o **moda**
#
# Nel caso della colonna "_Temperatura_" opteremo per sostituire i valori nulli con la _**media**_.

# %% [markdown]
# #### Perché questa scelta?
#
# Abbiamo scelto di eseguire una sostituione dei valori nulli con la media in quanto, osservando i valori della colonna "_**Temperatura**_" nel dataset, questi seguono una distribuzione alquanto simmetrica: infatti tutti i valori si trovano in un range compreso tra **36**˚C e **39**˚C (tralasciando il valore palesemente errato di 200˚C).

# %% [markdown]
# Quindi trasformiamo i valori "_Null_" della colonna "_Temperatura_" nella media della colonna tramite la funzione mean (che in questo dataset sono 20)

# %%
#trasformazione dei valori nulli nella media tramite fillna e mean
tr_clean['Temperatura'] = tr_clean['Temperatura'].fillna(tr_clean['Temperatura'].mean())

# %% [markdown]
# Verifichiamo adesso i valori null nella colonna "_Temperatura_".

# %%
tr_clean.isnull().sum()
# Out:
# Età                    0
# Genere                 0
# Frequenza Cardiaca    21
# SpO2                  20
# OssigenoTerapia       21
# DopoTest6Minuti       20
# Temperatura            0
# Allerta?              20
# StatoFumo              0
# dtype: int64

# %% [markdown]
# Andiamo adesso a gestire i valori "_Null_" nelle altre colonne.

# %% [markdown]
# Per quanto riguarda la **Frequenza cardiaca**, **SpO2**, **Ossigeno terapia** e **Dopo test 6 minuti** riteniamo più adatt eliminare le righe che presentano dei "_Null_", scelta che è stata presa anche sulla base della quantità delle righe contenenti valori "_Null_", che è al di sotto del 5% delle righe totali.

# %% [markdown]
# Andiamo a contare quante righe verrebbero eliminate.

# %%
#conteggio righe (axis = 1) nulle nell'intero dataset 
tr_clean.isnull().any(axis=1).sum()
# Out:
# np.int64(22)

# %% [markdown]
# Le righe che verrebbero eliminate da un dropna sono 22/569, quindi siamo intorno al **3,5%** delle righe totali.

# %%
tr_clean.isnull().sum()
# Out:
# Età                    0
# Genere                 0
# Frequenza Cardiaca    21
# SpO2                  20
# OssigenoTerapia       21
# DopoTest6Minuti       20
# Temperatura            0
# Allerta?              20
# StatoFumo              0
# dtype: int64

# %% [markdown]
# Andiamo adesso ad eliminare queste righe tramite la funzione dropna

# %%
tr_clean.dropna(inplace=True)

# %%
tr_clean.isnull().any()
# Out:
# Età                   False
# Genere                False
# Frequenza Cardiaca    False
# SpO2                  False
# OssigenoTerapia       False
# DopoTest6Minuti       False
# Temperatura           False
# Allerta?              False
# StatoFumo             False
# dtype: bool

# %% [markdown]
# Come possiamo vedere, adesso nessuna delle colonne presenta valori nulli

# %%
tr_clean.shape
# Out:
# (547, 9)

# %% [markdown]
# Esattamente 22 righe in meeno del dataset originale (569)

# %% [markdown]
# ### Valori errati
# In questa parte andremo ad indivuduare e gestire i valori palesemente errati del dataset

# %% [markdown]
# #### Possiamo visualizzare delle informazioni sulle variabili del dataset tramite la funzione "_describe_", per verificare se siano presenti valori palesemente errati.
# Verifichiamo questa proprietà sulle colonne del dataset.

# %%
tr_clean.describe()
# Out:
#                Età  Frequenza Cardiaca        SpO2  Temperatura
# count   547.000000          547.000000  547.000000   547.000000
# mean     71.530165           89.506399   94.177331    36.817916
# std      83.593231           21.835076    4.052720     7.038859
# min       6.000000           60.000000   86.000000    36.000000
# 25%      48.000000           75.000000   91.000000    36.000000
# 50%      75.000000           88.000000   95.000000    36.200000
# 75%      88.000000          100.000000   98.000000    36.600000
# max    1926.000000          400.000000  100.000000   200.000000

# %% [markdown]
# Dall'output della funzione describe sul dataset possiamo notare delle anomalie:
# - la colonna **Età** presenta valori palesemente errati, in quanto il suo valore massimo è **1926** anni
# - la colonna **Frequenza cardiaca** presenta valori palesemente errati, in quanto il suo valore massimo è di **400** bpm
# - infine, la colonna **Temperatura** presenta dei valori palesemente errati in quanto ha un valore massimo di **200**˚C
#
# Inoltre, da una precedente analisi dei valori possibili nella colonna "_**Allerta**_" è comparso un valore ambiguo "_true_", il quale verràgestito insieme agli altri casi.

# %% [markdown]
# #### Come gestiamo questi dati?
# Così come con i valori nulli abbiamo diverse scelte
# - eliminare la riga
# - sostituione con un valore plausibile (media, moda o mediana)
# - sostituire con un valore fisso
#
# Nel nostro caso andremo a eliminare le righe con valori palesemente errati.

# %%
tr_clean.shape
# Out:
# (547, 9)

# %%
tr_clean[tr_clean['Temperatura'] > 45].shape
#inanzitutto controlliamo quante righe verrebbero coinvolte dalla seguente interrogazione sul dataset
# Out:
# (1, 9)

# %% [markdown]
# Dato che il risultato è (1, 9) significa che il dataset risultante è una sola riga. Questo significa che una sola riga nell'intero dataset ha valore di temperatura maggiore di 45.
#
# Possiamo andare quindi a rimuovere la riga

# %%
tr_clean = tr_clean[tr_clean['Temperatura'] <= 45]

# %%
tr_clean['Temperatura'].describe()
#tr_clean.describe()
# Out:
# count    546.000000
# mean      36.519048
# std        0.829172
# min       36.000000
# 25%       36.000000
# 50%       36.200000
# 75%       36.600000
# max       39.900000
# Name: Temperatura, dtype: float64

# %%
tr_clean.shape
# Out:
# (546, 9)

# %% [markdown]
# Come possiamo notare, è stata coinvolta e eliminata una sola riga nella colonna _**Temperatura**_
#
# Adesso possiamo passare alle altre colonne: _**Frequenza cardiaca**_ e _**Età**_

# %%
tr_clean[tr_clean['Età'] > 120].shape
# Out:
# (1, 9)

# %% [markdown]
# Anche in questo caso si tratta di una sola riga, la quale possiamo rimuovere

# %%
tr_clean = tr_clean[tr_clean['Età'] <= 120]

# %%
tr_clean['Età'].describe()
#tr_clean.describe()
# Out:
# count    545.000000
# mean      68.148624
# std       26.077196
# min        6.000000
# 25%       48.000000
# 50%       75.000000
# 75%       88.000000
# max      109.000000
# Name: Età, dtype: float64

# %%
tr_clean.shape
# Out:
# (545, 9)

# %% [markdown]
# Come prima, una sola riga è stata rimossa dal dataset

# %% [markdown]
# Passiamo adesso alla colonna di _**Frequenza cardiaca**_

# %%
tr_clean[(tr_clean['Frequenza Cardiaca'] > 220) | (tr_clean['Frequenza Cardiaca'] < 30)].shape
# Out:
# (1, 9)

# %% [markdown]
# Come nei casi precedenti, solo una riga non rispetta la condizione

# %%
tr_clean = tr_clean[(tr_clean['Frequenza Cardiaca'] >= 30) & (tr_clean['Frequenza Cardiaca'] <= 220)]

# %%
tr_clean['Frequenza Cardiaca'].describe()
# Out:
# count    544.000000
# mean      88.887868
# std       17.345167
# min       60.000000
# 25%       75.000000
# 50%       88.000000
# 75%      100.000000
# max      144.000000
# Name: Frequenza Cardiaca, dtype: float64

# %%
tr_clean.shape
# Out:
# (544, 9)

# %% [markdown]
# Di nuovo, solo una riga è stata coinvolta nell'eliminazione

# %% [markdown]
# Passiamo a gestire la colonna _**Allerta**_

# %%
classi_ammesse = ["GREEN", "YELLOW", "RED"]
tr_clean[~(tr_clean['Allerta?'].isin(classi_ammesse))].shape
# Out:
# (1, 9)

# %% [markdown]
# Di nuovo, la colonna con un valore diverso da quelli ammessi è solo una

# %%
tr_clean = tr_clean[tr_clean['Allerta?'].isin(classi_ammesse)]

# %%
tr_clean['Allerta?'].unique()
# Out:
# array(['GREEN', 'RED', 'YELLOW'], dtype=object)

# %%
tr_clean.shape
# Out:
# (543, 9)

# %% [markdown]
# La nuova lunghezza del dataset è esattamente una riga di meno dell'originale

# %% [markdown]
# Adesso abbiamo quindi
# - dataset senza valori nulli
# - dataset senza valori palesemente sbagliati
#
# Possiamo quindi passare alla raffigurazione del dataset tramite **Boxplot**, **Pairplot** e **Matrice di corrrelazione**

# %% [markdown]
# ### Rappresentazione grafica
# In questa sezione andremo rappresentare il dataset tramite diversi grafici, tra cui
# - **Pairplot**
# - **Boxplot**
# -  **Matrice di correlazione**

# %%
print(tr_clean.dtypes)
# Out:
# Età                     int64
# Genere                 object
# Frequenza Cardiaca    float64
# SpO2                  float64
# OssigenoTerapia        object
# DopoTest6Minuti        object
# Temperatura           float64
# Allerta?               object
# StatoFumo              object
# dtype: object

# %% [markdown]
# Prima di fare questo, occorre effettuare una conversione delle colonne **categoriche** del nostro dataset in colonne **numeriche**

# %%
print("Classi colonna \"Genere\": ", tr_clean['Genere'].unique())
print("Classi colonna \"Ossigeno terapia\": ", tr_clean['OssigenoTerapia'].unique())
print("Classi colonna \"Allerta\": ", tr_clean['Allerta?'].unique())
print("Classi colonna \"Stato fumo\": ", tr_clean['StatoFumo'].unique())
# Out:
# Classi colonna "Genere":  ['F' 'M']
# Classi colonna "Ossigeno terapia":  ['no' 'venturi_mask' 'ox']
# Classi colonna "Allerta":  ['GREEN' 'RED' 'YELLOW']
# Classi colonna "Stato fumo":  ['Non-Fumatore' 'Ex-Fumatore' 'Fumatore']

# %%
#definiamo adesso delle mappe che ci aiurettanno a convertire le colonne categoriche in colonne numeriche
#mappa per il genere
mappa_genere = {
    'F' : 0, 'M' : 1
}
#mappa per ossigeno terapia
mappa_ossigeno_terapia = {
    'no' : 0, 'venturi_mask' : 1, 'ox' : 2
}
#mappa per allerta
mappa_allerta = {
    'GREEN' : 0, 'YELLOW' : 1, 'RED' : 2
}
#mappa per stato fumo
mappa_stato_fumo = {
    'Non-Fumatore' : 0, 'Ex-Fumatore' : 1, 'Fumatore' : 2
}

#adesso andiamo a mappare i valori nel loro formato numerico
tr_clean['Genere'] = tr_clean['Genere'].map(mappa_genere)
tr_clean['OssigenoTerapia'] = tr_clean['OssigenoTerapia'].map(mappa_ossigeno_terapia)
tr_clean['Allerta?'] = tr_clean['Allerta?'].map(mappa_allerta)
tr_clean['StatoFumo'] = tr_clean['StatoFumo'].map(mappa_stato_fumo)

# %%
#andiamo adesso a verificare i tipi di dato
print(tr_clean.dtypes)
# Out:
# Età                     int64
# Genere                  int64
# Frequenza Cardiaca    float64
# SpO2                  float64
# OssigenoTerapia         int64
# DopoTest6Minuti        object
# Temperatura           float64
# Allerta?                int64
# StatoFumo               int64
# dtype: object

# %% [markdown]
# Abbiamo adesso tutti tipi **numerici** (tranne la colonna "DopoTest6Minuti, che è booleana). Questo ci tornerà utile nella creazione di alcuni grafici, come la **Matrice di correlazione** o il **Pairplot**

# %%
tr_clean.head()
# Out:
#    Età  Genere  Frequenza Cardiaca  SpO2  OssigenoTerapia DopoTest6Minuti  \
# 0   43       0               104.0  94.0                0           False
# 1   79       1                85.0  89.0                0           False
# 2   81       1               114.0  86.0                0           False
# 3   81       1                92.0  86.0                0           False
# 4   48       0                87.0  93.0                0           False
#
#    Temperatura  Allerta?  StatoFumo
# 0         36.0         0          0
# 1         36.3         0          1
# 2         36.2         2          2
# 3         36.5         2          0
# 4         36.0         1          0

# %% [markdown]
# Passiamo adesso alla raffigurazione vera e propria dei dati

# %% [markdown]
# Cominciamo fcendo vedere il **Pairplot** del nostro intero dataset

# %%
#mapping delle classi della colonna "Allerta" nei loro colori
#0 = GREEEN, 1 = YELLOW, 2 = RED
palette = {
     0: "green", 
     1: "gold",
     2: "red"
}

sns.pairplot(tr_clean, hue="Allerta?", diag_kind='kde', palette=palette)
plt.suptitle('Pairplot per Allerta', y=1.02)
plt.show()

# %% [markdown]
# Da questo Pairplot possiamo fare diverse considerazioni:
# - **SpO2**:  I punti verdi (allerta 0) si concentrano sui valori alti di SpO2 (95-100%), mentre i rossi (allerta 2) stanno sui valori bassi (80-95%). Questa osservazione verrà confermata anche successivamente quando faremo vedere la matrice di correlazione.
# - **Temperatura**: I punti rossi (allerta 2) tendono a concentrarsi su temperature più elevate

# %% [markdown]
# Passiamo adesso ai grafici **Boxplot**

# %%
sns.boxplot(data=tr_clean, hue ="Allerta?", x="Allerta?", y="SpO2", palette={0: "green", 1:"gold", 2:"red"})
plt.title("Livello SpO2 per Allerta")
plt.xlabel("Allerta (0 = Verde, 1 = Gialla, 2 = Rossa")
plt.ylabel("SpO2 (%)")
plt.show()

# %% [markdown]
# Questo grafico conferma l'osservazione avanzata analizzando il Pairplot: a livelli di **Allerta** maggiori corrispondono livelli di **SpO2** minori.
#
# Presenza di **Outlier** in tutte le classi di allerta

# %%
sns.boxplot(data=tr_clean, hue ="Allerta?", x="Genere", y="SpO2", palette={0: "green", 1:"gold", 2:"red"})
plt.title("Livello SpO2 per Genere")
plt.xlabel("Genere (0 = F, 1 = M)")
plt.ylabel("SpO2 (%)")
plt.show()

# %% [markdown]
# Da questo **Boxplot** possiamo vedere delle differenze di Genere in base al livello di Allerta e SpO2:
# - nelle **donne** troviamo un range più ampio di tutti i livelli di allerta
# - negli **uomini** troviamo invece delle distribuzioni più compatte e concentrate, oltre che dei livelli di SpO2 più alti per quanto riguarda in Allerta verde
#
# Anche in questo caso sono presente degli **Outlier** in entrambi i Generi

# %%
sns.boxplot(data=tr_clean, hue ="Allerta?", x="Genere", y="Temperatura", palette={0: "green", 1:"gold", 2:"red"})
plt.title("Livello Temperatura per Genere")
plt.xlabel("Genere (0 = F, 1 = M)")
plt.ylabel("Temperatura (˚C)")
plt.show()

# %% [markdown]
# Questo grafico mostra i valori di temperatura in base all'Allerta e una divisione per genere.
#
# Dal Boxplot possiamo osservare:
# - una progessione della Temperatura **meno netta** rispetto ai valori di SpO2
#
# Possiamo ossrevare invece delle differenze abbastanzi signficative tra i due Generi:
# - nelle **donne** troviamo un aumento della Temperatura **più drammatico** (all'aumentare del livello dall'Allerta) rispetto agli **uomini**
# - negli **uomini** possiamo osservare una variazione minima della Temperatura atraverso i vari livelli di Allerta
#
# Come negli altri casi, possiamo notare la presenza di diversi **Outlier**

# %%
sns.boxplot(data=tr_clean, hue ="Allerta?", x="StatoFumo", y="SpO2", palette={0: "green", 1:"gold", 2:"red"})
plt.title("Livello SpO2 per Status fumo")
plt.xlabel("Stato fumo (0 = Non-Fumatore, 1 = Ex-Fumatore, 2 = Fumatore")
plt.ylabel("SpO2 (%)")
plt.show()

# %% [markdown]
# Questo Boxplot mostra, per i tre diversi livelli di Allerta, i livelli di SpO2 per le 3 diverse categorie di Status sul fumo
#
# Possiamo vedere infatti come nella classe dei "**Non_Fumatori**"(0) il livello di SpO2 sia più elevato in Allerta verde rispetto alle altre categorie di Allerta
#
# Come nei casi precedenti, anche qui sono presenti **Outlier**

# %%
sns.boxplot(data=tr_clean, hue="OssigenoTerapia", x="OssigenoTerapia", y="SpO2", palette="pastel")
plt.title("SpO₂ per status fumo")
plt.xlabel("Tipo di Ossigeno Terapia (0=no, 1=venturi_mask ,2=ox)")
plt.ylabel("SpO₂ (%)")
plt.show()

# %% [markdown]
# Questo Boxplot mostra i livelli di SpO2 relativo alle diverse condizioni relative all'Ossigeno terapia
#
# Si noti come i pazienti senza Ossigeno terapia e quelli con Terapia Ossigeno abbiano valori di SpO2 più **variabili**; hanno difatti un range di valori **molto più ampio** (86% - 100%) rispetto ai pazienti che hanno una terapia con Ventimask (88% - 100%)

# %%
corr = tr_clean.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Matrice di Correlazione")
plt.show()

# %% [markdown]
# Dalla Matrice di Correlazione possiamo osservare queli della variabili del dataset siano in relazione tra loro, in particolare
# - **Allerta e Temperatura**
# - **Allerta e Ossigeno Terapia**
# - **Frequenza Cardiaca e Allerta**
# - **Ossigeno Terapia e Frequenza Cardiaca**
# - **Allerta e SpO2** (correlazione **negativa**)

# %% [markdown]
# ---

# %% [markdown]
# # Terzo Task
# Considerando i classificatori progettati ed implementati in Python nel Primo task, valutare le
# performance ottenute da ognuno di essi sul file "training.csv" o su qualche suo sottoinsieme,
# cercando di ottimizzare le prestazioni dei classificatori
